# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Simple Linear Regression with Sacramento Real Estate Data
#
# _Authors: Matt Brems, Sam Stack_
#
# ---
#
# In this lab you will hone your EDA skills and practice constructing simple linear regressions using a dataset on Sacramento real estate sales.  The dataset contains information on qualities of the property, location of the property, and time of sale.

# %% [markdown]
# ### 1. Read in the Sacramento housing data set.

# %%
sac_csv = '../data/sacramento_real_estate_transactions.csv'

# %%
from IPython.display import HTML
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats

plt.style.use('fivethirtyeight')
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %% [markdown]
# ### 2. Conduct exploratory data analysis on this data set.
#
# **Report any notable findings here and any steps you take to clean/process data.**
#
# > **Note:** These EDA checks should be done on every data set we give you. If you find yourself checking for, say, missing/corrupted data over and over, it might be to your long-term benefit to have a function that you can re-use every time you're given some new data.

# %%
sac = pd.read_csv(sac_csv)
sac.head(10)
# Each row is a piece of real estate
# 'SACRAMENTO' is most represented city
# No of beds goes from 0 to 8
# No of baths goes from 0 to 5
# Sq_ft measurements, where 171 entries are missing (i.e. '0')
# Four types of homes: Residential, Condo, Multi-Family and Unkown (1 which has no baths, beds or sq_ft but high price)

# 'price' is response variable (y)
# 'city', 'type', 'sq_ft', 'beds', 'baths' are in features matrix (X)
# Out:
#                             street            city    zip state  beds  baths  \
# 0                     3526 HIGH ST      SACRAMENTO  95838    CA     2      1
# 1                      51 OMAHA CT      SACRAMENTO  95823    CA     3      1
# 2                   2796 BRANCH ST      SACRAMENTO  95815    CA     2      1
# 3                 2805 JANETTE WAY      SACRAMENTO  95815    CA     2      1
# 4                  6001 MCMAHON DR      SACRAMENTO  95824    CA     2      1
# 5               5828 PEPPERMILL CT      SACRAMENTO  95841    CA     3      1
# 6              6048 OGDEN NASH WAY      SACRAMENTO  95842    CA     3      2
# 7                    2561 19TH AVE      SACRAMENTO  95820    CA     3      1
# 8  11150 TRINITY RIVER DR Unit 114  RANCHO CORDOVA  95670    CA     2      2
# 9                     7325 10TH ST       RIO LINDA  95673    CA     3      2
#
#    sq__ft         type                     sale_date  price   latitude  \
# 0     836  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913
# 1    1167  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902
# 2     796  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305
# 3     852  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835
# 4     797  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470
# 5    1122        Condo  Wed May 21 00:00:00 EDT 2008  89921  38.662595
# 6    1104  Residential  Wed May 21 00:00:00 EDT 2008  90895  38.681659
# 7    1177  Residential  Wed May 21 00:00:00 EDT 2008  91002  38.535092
# 8     941        Condo  Wed May 21 00:00:00 EDT 2008  94905  38.621188
# 9    1146  Residential  Wed May 21 00:00:00 EDT 2008  98937  38.700909
#
#     longitude
# 0 -121.434879
# 1 -121.431028
# 2 -121.443839
# 3 -121.439146
# 4 -121.435768
# 5 -121.327813
# 6 -121.351705
# 7 -121.481367
# 8 -121.270555
# 9 -121.442979

# %%
sac.shape
# Out:
# (985, 12)

# %%
sac.dtypes
# Out:
# street        object
# city          object
# zip            int64
# state         object
# beds           int64
# baths          int64
# sq__ft         int64
# type          object
# sale_date     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %%
#sac.columns
sac.rename(columns={'sq__ft' : 'sq_ft'}, inplace=True)

# %%
sac.isnull().sum()
# Out:
# street       0
# city         0
# zip          0
# state        0
# beds         0
# baths        0
# sq_ft        0
# type         0
# sale_date    0
# price        0
# latitude     0
# longitude    0
# dtype: int64

# %%
sac['state'].value_counts(dropna=False)
# Out:
# CA    984
# AC      1
# Name: state, dtype: int64

# %%
# Zip code is better as a string object (categorical) and will be removed from features
sac['zip'] = sac['zip'].astype(str)

# %%
# price and square footage are negative values
sac[sac['price'] < 1]
# Out:
#                street        city    zip state  beds  baths  sq_ft   type  \
# 703  1900 DANBROOK DR  SACRAMENTO  95835    AC     1      1   -984  Condo
#
#                         sale_date   price    latitude  longitude
# 703  Fri May 16 00:00:00 EDT 2008 -210944 -121.503471  38.668433

# %%
# square footage also equals zero
sac[sac['type'] == 'Unkown']
# Out:
#                 street             city    zip state  beds  baths  sq_ft  \
# 757  6007 MARYBELLE LN  SHINGLE SPRINGS  95682    CA     0      0      0
#
#        type                     sale_date   price  latitude   longitude
# 757  Unkown  Fri May 16 00:00:00 EDT 2008  275000  38.64347 -120.888183

# %%
# Remove rows 703 & 757
sac.drop([703, 757], inplace = True)

# %%
# Drop columns ['street', 'zip', 'state', 'sale_date', 'latitude', 'longitude', 'price'] for feature matrix

# %% [markdown]
# ### 3. Our goal will be to predict price. List variables that you think qualify as predictors of price in a SLR model.
#
# **For each of these variables you believe to be valid potential predictors in an SLR model, generate a plot showing the relationship between the independent variable and dependent variable.**

# %%
# 'city' vs 'price'
# coloured bar plots represent mean count and black bars indicate the error margins
# e.g. Granite Bay brings in reliable number of sales

sns.barplot(x='city', y='price', data=sac);
plt.xticks(rotation=90);

# %%
# 'type' vs 'price'
# residential and multi-family are majority of sales but condos are smaller...

sns.barplot(x='type', y='price', data=sac);

# %%
# 'sq_ft' vs 'price'
# visually the best predictor as price increases when square footage increases

sns.lmplot(x='sq__ft', y='price', data=sac)
plt.show();

# %%
# 'beds' vs 'price'
# price varies widely when residence has 5-6 beds

sns.lineplot(x='beds', y='price', data=sac);

# %%
# 'baths' vs 'price'
# visually this is better predictor than beds

sns.lineplot(x='baths', y='price', data=sac);

# %% [markdown]
# ### 4. Which variable would be the best predictor of Y in a SLR model? Why?

# %%
# sq_ft shows strongest positive linear relationship with price
# 170 rows where square footage is not provided - REMOVE FOR MODEL DATA AS USELESS
sac[sac['sq__ft'] == 0]
# Out:
#                        street             city    zip state  beds  baths  \
# 73              17 SERASPI CT       SACRAMENTO  95834    CA     0      0
# 89           2866 KARITSA AVE       SACRAMENTO  95833    CA     0      0
# 100     12209 CONSERVANCY WAY   RANCHO CORDOVA  95742    CA     0      0
# 121       5337 DUSTY ROSE WAY   RANCHO CORDOVA  95742    CA     0      0
# 126       2115 SMOKESTACK WAY       SACRAMENTO  95833    CA     0      0
# ..                        ...              ...    ...   ...   ...    ...
# 934  1550 TOPANGA LN Unit 207          LINCOLN  95648    CA     0      0
# 947     1525 PENNSYLVANIA AVE  WEST SACRAMENTO  95691    CA     0      0
# 966          9197 CORTINA CIR        ROSEVILLE  95678    CA     3      2
# 970             3557 SODA WAY       SACRAMENTO  95834    CA     0      0
# 973      2181 WINTERHAVEN CIR     CAMERON PARK  95682    CA     3      2
#
#      sq__ft         type                     sale_date   price   latitude  \
# 73        0  Residential  Wed May 21 00:00:00 EDT 2008  206000  38.631481
# 89        0  Residential  Wed May 21 00:00:00 EDT 2008  244500  38.626671
# 100       0  Residential  Wed May 21 00:00:00 EDT 2008  263500  38.553867
# 121       0  Residential  Wed May 21 00:00:00 EDT 2008  320000  38.528575
# 126       0  Residential  Wed May 21 00:00:00 EDT 2008  339500  38.602416
# ..      ...          ...                           ...     ...        ...
# 934       0        Condo  Thu May 15 00:00:00 EDT 2008  188000  38.884170
# 947       0  Residential  Thu May 15 00:00:00 EDT 2008  200100  38.569943
# 966       0        Condo  Thu May 15 00:00:00 EDT 2008  220000  38.793152
# 970       0  Residential  Thu May 15 00:00:00 EDT 2008  224000  38.631026
# 973       0  Residential  Thu May 15 00:00:00 EDT 2008  224500  38.697570
#
#       longitude
# 73  -121.501880
# 89  -121.525970
# 100 -121.219141
# 121 -121.228600
# 126 -121.542965
# ..          ...
# 934 -121.270222
# 947 -121.527539
# 966 -121.290025
# 970 -121.501879
# 973 -120.995739
#
# [171 rows x 12 columns]

# %%
sac_model = sac[sac.sq__ft != 0]
sac_model.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
y = sac_model['price'] # target variable
X = np.array(sac_model['sq__ft']).reshape(-1, 1) # predictor variable

# %% [markdown]
# ### 5. Build a function that will take in two lists `Y` and `X` and returns the intercept and slope coefficients that minimize SSE.
#
# `Y` is the target variable and `X` is the predictor variable.
#
# - **Test your function on price and the variable you determined was the best predictor in Problem 4.**
# - **Report the slope and intercept.**

# %%
X
# Out:
# array([[ 836],
#        [1167],
#        [ 796],
#        [ 852],
#        [ 797],
#        [1122],
#        [1104],
#        [1177],
#        [ 941],
#        [1146],
#        [ 909],
#        [1289],
#        [ 871],
#        [1020],
#        [1022],
#        [1134],
#        [ 844],
#        [ 795],
#        [ 588],
#        [1356],
#        [1118],
#        [1329],
#        [1240],
#        [1601],
#        [ 901],
#        [1088],
#        [ 963],
#        [1119],
#        [1380],
#        [1248],
#        [1039],
#        [1152],
#        [1380],
#        [1116],
#        [1039],
#        [1418],
#        [1082],
#        [1472],
#        [1146],
#        [ 760],
#        [1304],
#        [1207],
#        [1056],
#        [1043],
#        [1587],
#        [1120],
#        [1580],
#        [1955],
#        [1656],
#        [1477],
#        [1188],
#        [1590],
#        [1463],
#        [1714],
#        [1185],
#        [1406],
#        [1943],
#        [1172],
#        [1152],
#        [1851],
#        [1215],
#        [1130],
#        [1603],
#        [1479],
#        [1420],
#        [1280],
#        [1586],
#        [1362],
#        [2162],
#        [1266],
#        [1715],
#        [1820],
#        [ 936],
#        [1511],
#        [1590],
#        [1596],
#        [1341],
#        [2136],
#        [1616],
#        [1478],
#        [1287],
#        [1277],
#        [1448],
#        [2235],
#        [2093],
#        [1193],
#        [2163],
#        [1269],
#        [ 958],
#        [2508],
#        [1305],
#        [1591],
#        [1326],
#        [1843],
#        [1921],
#        [2790],
#        [1541],
#        [1018],
#        [1672],
#        [1380],
#        [ 975],
#        [2372],
#        [1446],
#        [1284],
#        [3009],
#        [3612],
#        [2056],
#        [1993],
#        [1857],
#        [1126],
#        [2213],
#        [2494],
#        [1843],
#        [1520],
#        [2800],
#        [2309],
#        [2367],
#        [3516],
#        [1914],
#        [1690],
#        [2725],
#        [2354],
#        [2185],
#        [1801],
#        [1961],
#        [3134],
#        [1915],
#        [2734],
#        [2110],
#        [3164],
#        [3599],
#        [2054],
#        [1830],
#        [1627],
#        [3440],
#        [2846],
#        [2359],
#        [2052],
#        [3433],
#        [3615],
#        [2687],
#        [2724],
#        [3440],
#        [3508],
#        [2462],
#        [2325],
#        [ 795],
#        [1099],
#        [ 840],
#        [ 800],
#        [ 746],
#        [1067],
#        [1316],
#        [1337],
#        [ 868],
#        [ 924],
#        [ 610],
#        [1220],
#        [ 722],
#        [1643],
#        [ 722],
#        [1080],
#        [1039],
#        [1051],
#        [ 967],
#        [1098],
#        [1050],
#        [1110],
#        [ 888],
#        [1120],
#        [1080],
#        [ 957],
#        [ 952],
#        [1211],
#        [1264],
#        [1080],
#        [1266],
#        [ 994],
#        [1202],
#        [ 722],
#        [1448],
#        [1188],
#        [1183],
#        [1320],
#        [1117],
#        [1364],
#        [1310],
#        [1006],
#        [1104],
#        [ 810],
#        [1123],
#        [ 904],
#        [1156],
#        [1321],
#        [1392],
#        [1439],
#        [1159],
#        [1671],
#        [1740],
#        [1265],
#        [1007],
#        [1716],
#        [1685],
#        [1829],
#        [1555],
#        [1120],
#        [1137],
#        [1174],
#        [1393],
#        [1289],
#        [1799],
#        [1953],
#        [ 723],
#        [ 948],
#        [1578],
#        [1317],
#        [1360],
#        [1522],
#        [1751],
#        [1465],
#        [1605],
#        [1475],
#        [1216],
#        [1315],
#        [1567],
#        [1776],
#        [2187],
#        [1291],
#        [1503],
#        [2491],
#        [1269],
#        [1176],
#        [1456],
#        [1498],
#        [1574],
#        [2085],
#        [2170],
#        [1595],
#        [1567],
#        [1253],
#        [1768],
#        [2030],
#        [1531],
#        [1653],
#        [2056],
#        [2494],
#        [1450],
#        [2169],
#        [1440],
#        [1527],
#        [1401],
#        [1411],
#        [1284],
#        [2307],
#        [1329],
#        [1910],
#        [1981],
#        [2205],
#        [1449],
#        [1258],
#        [2575],
#        [ 539],
#        [2208],
#        [1108],
#        [1595],
#        [2159],
#        [2295],
#        [1838],
#        [1900],
#        [1718],
#        [3389],
#        [3260],
#        [2016],
#        [2607],
#        [2724],
#        [3746],
#        [3192],
#        [1247],
#        [2581],
#        [2068],
#        [3992],
#        [3397],
#        [3881],
#        [1598],
#        [1929],
#        [3070],
#        [3984],
#        [2222],
#        [3838],
#        [2846],
#        [2484],
#        [1624],
#        [ 840],
#        [ 484],
#        [ 970],
#        [ 623],
#        [ 932],
#        [ 796],
#        [ 834],
#        [ 834],
#        [ 924],
#        [ 795],
#        [1250],
#        [ 984],
#        [1013],
#        [1012],
#        [ 795],
#        [ 918],
#        [1082],
#        [ 964],
#        [1404],
#        [ 625],
#        [ 888],
#        [1120],
#        [1331],
#        [1014],
#        [1448],
#        [ 966],
#        [ 779],
#        [ 836],
#        [1100],
#        [1174],
#        [1207],
#        [1995],
#        [ 804],
#        [ 958],
#        [1366],
#        [ 901],
#        [ 696],
#        [1080],
#        [1104],
#        [ 972],
#        [1390],
#        [1354],
#        [ 795],
#        [ 780],
#        [1587],
#        [1209],
#        [1139],
#        [1690],
#        [1245],
#        [1416],
#        [1300],
#        [1120],
#        [1590],
#        [1407],
#        [1516],
#        [1646],
#        [1676],
#        [1370],
#        [1370],
#        [1351],
#        [1152],
#        [1452],
#        [ 990],
#        [1162],
#        [1182],
#        [1112],
#        [1100],
#        [1280],
#        [1280],
#        [1039],
#        [1159],
#        [1917],
#        [1520],
#        [1204],
#        [1120],
#        [1436],
#        [1451],
#        [1638],
#        [1000],
#        [1152],
#        [1154],
#        [1353],
#        [1329],
#        [1356],
#        [1505],
#        [1009],
#        [1144],
#        [ 930],
#        [1766],
#        [1940],
#        [1776],
#        [1258],
#        [1872],
#        [1112],
#        [1856],
#        [1939],
#        [ 998],
#        [1758],
#        [2142],
#        [ 950],
#        [1739],
#        [1516],
#        [ 988],
#        [1555],
#        [1212],
#        [1871],
#        [1302],
#        [ 756],
#        [2026],
#        [1375],
#        [1250],
#        [1058],
#        [1187],
#        [1324],
#        [1936],
#        [2382],
#        [1427],
#        [1678],
#        [1798],
#        [2652],
#        [1816],
#        [3076],
#        [1844],
#        [1306],
#        [2447],
#        [1176],
#        [1182],
#        [1160],
#        [1424],
#        [1574],
#        [1830],
#        [1724],
#        [1255],
#        [2175],
#        [1904],
#        [1808],
#        [2711],
#        [1713],
#        [1457],
#        [2724],
#        [1468],
#        [2550],
#        [1928],
#        [1922],
#        [1343],
#        [1510],
#        [ 960],
#        [1559],
#        [1624],
#        [2992],
#        [2109],
#        [1524],
#        [1248],
#        [1876],
#        [1851],
#        [2218],
#        [1394],
#        [1410],
#        [3468],
#        [2346],
#        [2347],
#        [1659],
#        [2442],
#        [2155],
#        [1810],
#        [2789],
#        [1606],
#        [2166],
#        [1871],
#        [1800],
#        [1683],
#        [1596],
#        [1179],
#        [1639],
#        [3281],
#        [1697],
#        [2085],
#        [1744],
#        [1939],
#        [1788],
#        [1691],
#        [2002],
#        [4303],
#        [4246],
#        [2274],
#        [3056],
#        [2503],
#        [1905],
#        [1320],
#        [3037],
#        [3741],
#        [2660],
#        [3357],
#        [2896],
#        [2025],
#        [3788],
#        [3670],
#        [1166],
#        [ 838],
#        [ 904],
#        [1032],
#        [ 904],
#        [1080],
#        [ 990],
#        [ 900],
#        [ 861],
#        [ 906],
#        [1011],
#        [1089],
#        [ 832],
#        [ 800],
#        [1292],
#        [ 810],
#        [1064],
#        [ 911],
#        [ 846],
#        [1320],
#        [1410],
#        [1115],
#        [1169],
#        [1164],
#        [1341],
#        [1219],
#        [1127],
#        [1272],
#        [1253],
#        [1120],
#        [1118],
#        [1890],
#        [1260],
#        [1400],
#        [1264],
#        [1060],
#        [1132],
#        [1466],
#        [1092],
#        [1628],
#        [ 960],
#        [1075],
#        [1428],
#        [1358],
#        [2475],
#        [1410],
#        [1711],
#        [1483],
#        [1140],
#        [1549],
#        [1410],
#        [1240],
#        [1712],
#        [1580],
#        [1669],
#        [1029],
#        [1103],
#        [2161],
#        [1650],
#        [1320],
#        [1200],
#        [1170],
#        [1199],
#        [1695],
#        [1157],
#        [1410],
#        [1174],
#        [1593],
#        [1093],
#        [1770],
#        [1436],
#        [1124],
#        [1139],
#        [1638],
#        [1328],
#        [1273],
#        [1082],
#        [1578],
#        [ 796],
#        [1386],
#        [1452],
#        [1513],
#        [1578],
#        [1736],
#        [1473],
#        [1150],
#        [1127],
#        [1144],
#        [ 972],
#        [2306],
#        [1479],
#        [1040],
#        [1430],
#        [1800],
#        [1953],
#        [1120],
#        [1232],
#        [-984],
#        [2329],
#        [1351],
#        [1376],
#        [1300],
#        [1566],
#        [1115],
#        [1032],
#        [1419],
#        [1261],
#        [1637],
#        [1776],
#        [1338],
#        [2254],
#        [1441],
#        [1991],
#        [2126],
#        [1094],
#        [1462],
#        [2258],
#        [1074],
#        [2111],
#        [1686],
#        [1915],
#        [2367],
#        [1962],
#        [1406],
#        [1789],
#        [1876],
#        [1235],
#        [2504],
#        [1676],
#        [1367],
#        [1899],
#        [1636],
#        [1828],
#        [1438],
#        [1451],
#        [1520],
#        [1506],
#        [2605],
#        [1196],
#        [1621],
#        [1811],
#        [1540],
#        [1543],
#        [2494],
#        [1650],
#        [2214],
#        [2280],
#        [1443],
#        [1582],
#        [1857],
#        [1735],
#        [2096],
#        [1720],
#        [2160],
#        [1382],
#        [1721],
#        [1328],
#        [1982],
#        [1144],
#        [1623],
#        [1457],
#        [2555],
#        [1577],
#        [2592],
#        [1401],
#        [1502],
#        [1327],
#        [1800],
#        [2169],
#        [2457],
#        [2004],
#        [2212],
#        [3134],
#        [1360],
#        [1276],
#        [2962],
#        [1888],
#        [1548],
#        [2109],
#        [2484],
#        [2258],
#        [2212],
#        [1616],
#        [2372],
#        [2606],
#        [2877],
#        [2960],
#        [2172],
#        [2100],
#        [1795],
#        [2295],
#        [2577],
#        [1727],
#        [1485],
#        [1655],
#        [2049],
#        [2875],
#        [2199],
#        [1304],
#        [2334],
#        [2278],
#        [1493],
#        [2787],
#        [2824],
#        [3261],
#        [2053],
#        [2379],
#        [3173],
#        [1348],
#        [1252],
#        [3229],
#        [3863],
#        [2356],
#        [3579],
#        [4400],
#        [5822],
#        [1512],
#        [ 611],
#        [ 876],
#        [ 933],
#        [ 864],
#        [1011],
#        [1158],
#        [1092],
#        [ 956],
#        [1139],
#        [1058],
#        [1040],
#        [1354],
#        [1051],
#        [ 682],
#        [1161],
#        [1004],
#        [1229],
#        [1249],
#        [1161],
#        [1010],
#        [1462],
#        [1269],
#        [1188],
#        [1570],
#        [1093],
#        [ 962],
#        [1089],
#        [1127],
#        [1309],
#        [ 970],
#        [1144],
#        [1000],
#        [1206],
#        [1285],
#        [1543],
#        [ 884],
#        [1019],
#        [1392],
#        [ 924],
#        [1217],
#        [1670],
#        [1302],
#        [1488],
#        [1373],
#        [1381],
#        [1265],
#        [ 881],
#        [1608],
#        [1344],
#        [1202],
#        [1104],
#        [1859],
#        [1232],
#        [1638],
#        [1177],
#        [1582],
#        [ 904],
#        [1340],
#        [1204],
#        [1477],
#        [1497],
#        [ 960],
#        [1428],
#        [1039],
#        [1529],
#        [1892],
#        [1887],
#        [1294],
#        [1638],
#        [1677],
#        [1073],
#        [1231],
#        [1175],
#        [1416],
#        [1358],
#        [1609],
#        [1968],
#        [1089],
#        [1296],
#        [1189],
#        [ 795],
#        [1371],
#        [1310],
#        [1262],
#        [1740],
#        [1517],
#        [1450],
#        [1416],
#        [ 888],
#        [1882],
#        [1302],
#        [1418],
#        [1319],
#        [1770],
#        [1627],
#        [1040],
#        [ 960],
#        [1456],
#        [1450],
#        [1358],
#        [1329],
#        [1715],
#        [1262],
#        [2280],
#        [1477],
#        [1216],
#        [1685],
#        [1362]], dtype=int64)

# %%
# Function takes Series and/or arrays and uses SciKit-Learn library to get optimal slope and intercept

def intercept_and_coef(X, y):
    from sklearn.linear_model import LinearRegression
    lr = LinearRegression()
    lr.fit(X, y)
    
    coefficients = lr.coef_
    intercept = lr.intercept_
    
    return intercept, coefficients

# %%
intercept_and_coef(X, y)
# Out:
# (28521.05799033254, array([126.14428564]))

# %%
# To get the optimal Coefficient (slope) and y-intercept without SciKit-Learn

import numpy as np
import scipy.stats

# This takes lists only
def lin_reg(x, y):
    
    # In SLR, correlation coefficient multiplied by the std dev of y divided by std dev of x equals optimal slope.
    beta_1 = (scipy.stats.pearsonr(x, y)[0]) * (np.std(y) / np.std(x))
    
    # Pearson Corr Coef returns tuple so it needs to be indexed
    # Optimal intercept is found by: mean(y) - b1 * mean(x)
    beta_0 = np.mean(y) - (beta_1 * np.mean(x)) 
    
    print('The Optimal Y Intercept is ', beta_0)
    print('The Optimal slope is ', beta_1)

# %%
Y = y.values
X = sac_model['sq__ft'].values

lin_reg(X, Y)
# Out:
# The Optimal Y Intercept is  28521.057990332512
# The Optimal slope is  126.14428563928885

# %% [markdown]
# ### 6. Interpret the intercept. Interpret the slope.

# %% [markdown]
# The intercept should be the constant *y* value that our data starts around, meaning from this point on, as *x* increases so does the *y* value from this point.
#
# The intercept is an "offset". Without the intercept our regression line would be forced to pass through the origin.
#
# The slope is the increase in target ('price') variable for a 1-unit increase in predictor variable ('sq_ft').
#
# So, for every 1-unit sq_ft increase, there is an associated increase of ~125 dollars.

# %% [markdown]
# ### 7. Give an example of how this model could be used for prediction and how this model could be used for inference.
#
# **Be sure to make it clear which example is associated with prediction and which is associated with inference.**

# %% [markdown]
# Prediction
#
# You are a real estate agent with a separate database on house characteristics and locations.
# You want to estimate the most likely price that one of these houses will sell at based on the model that we built using this data.
#
# Inference
#
# You work for an architecture company that wants to understand what characteristics of a house and what areas are associated with perceived value. You have some hypotheses about what makes a house valuable but you would like to test these hypotheses.

# %% [markdown]
# ### 8: [Bonus] Using the model you came up with in Problem 5, calculate and plot the residuals.

# %%
# Formula for prediction values: y = 29984.36 + 125.31x
# Create a list of predicted values

y_pred = []

for x in sac_model['sq_ft']:
    y = 29984.36 + (125.31 * x)
    y_pred.append(y)

# %%
import matplotlib.pyplot as plt

plt.scatter(X, sac_model['price']);
plt.plot(X, y_pred, 'r', linewidth=0.5);
plt.xlabel('Square Feet area');
plt.ylabel('Price');
plt.show();

# %%
# Add Prediction values as new column
sac_model['y_predictions'] = y_pred
# Out:
# C:\Users\shmel\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Add Residuals values as new column 
# (the difference between actual values and predicted values)
sac_model['residuals'] = abs(sac_model['price'] - sac_model['y_predictions'])
# Out:
# C:\Users\shmel\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sac_model['residuals'].mean()
# Out:
# 60221.8004551046

# %%
# Plot to show linear forecast
fig = plt.figure(figsize=(20,20))

# change fontsize of minor ticks label
plot = fig.add_subplot(111)
plot.tick_params(axis='both', which='major', labelsize=20)

# get the axis of that figure
ax = plt.gca()

# plot a scatter plot on it with our data
ax.scatter(x=sac_model['sq_ft'], y=sac_model['price'], c='k')
ax.plot(sac_model['sq_ft'], sac_model['y_predictions'], color='r');

# %%
# Now, plot with residuals
fig = plt.figure(figsize=(20,20))

# change the fontsize of minor ticks label
plot = fig.add_subplot(111)
plot.tick_params(axis='both', which='major', labelsize=20)

# get the axis of that figure
ax = plt.gca()

# plot a scatter plot on it with our data
ax.scatter(x=sac_model['sq_ft'], y=sac_model['price'], c='k')
ax.plot(sac_model['sq_ft'], sac_model['y_predictions'], color='r');

# iterate over predictions
for _, row in sac_model.iterrows():
    plt.plot((row['sq_ft'], row['sq_ft']), (row['price'], row['y_predictions']), 'b-')

# %%
# One more plot, lets look how our Predictions compared to the true values.
sns.lmplot(x='price', y='y_predictions', data=sac_model);

# %%
# Adding another independent variable could provide tighter fit of model to data predictions
